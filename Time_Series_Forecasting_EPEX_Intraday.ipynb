# %% [markdown]
# <a href="https://colab.research.google.com/github/RetoHe/epex-spot-intraday-timeseries-analysis/blob/main/Time_Series_Forecasting_EPEX_Intraday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Time Series Forecasting with EPEX Spot Intraday Data
# ### Basic Feature Engineering for Time Series inspired from *Introduction to Time Series Forecasting with Python* from Jason Brownlee.

# %% [markdown]
# ## Installieren der Requirements

# %%
# %%capture
! pip install pysftp

# %%
# %%capture
# !pip install statsmodels

# %%
import pysftp
import pandas as pd

# %% [markdown]
# ## Verbindung zu SFTP Server

# %%
# %%capture
cnopts = pysftp.CnOpts()
cnopts.hostkeys = None
# Out:
# /usr/local/lib/python3.7/dist-packages/pysftp/__init__.py:61: UserWarning: Failed to load HostKeys from /root/.ssh/known_hosts.  You will need to explicitly load HostKeys (cnopts.hostkeys.load(filename)) or disableHostKey checking (cnopts.hostkeys = None).
#   warnings.warn(wmsg, UserWarning)

# %%
sftp = pysftp.Connection(host="XXXXX", username="XXXXX", password="XXXXX", cnopts=cnopts)

# %%
sftp.chdir("/germany/Intraday Continuous/EOD/Transactions")

# %%
# !mkdir data

# %% [markdown]
# ## Download der Daten

# %%
german_dir = "/germany/Intraday Continuous/EOD/Transactions/"
# just export one single day of 2021
for element in sftp.listdir():
    if element[-3:] == "csv":
        new_path = german_dir + element
        sftp.get(new_path, "data/intradaydata_DE_{}.csv".format(element[29:40]))
        break
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-84-5bb4f94aa40a> in <module>()
#       1 german_dir = "/germany/Intraday Continuous/EOD/Transactions/"
#       2
# ----> 3 for element in sftp.listdir():
#       4     if element[-3:] == "csv":
#       5         new_path = german_dir + element
#
# /usr/local/lib/python3.7/dist-packages/pysftp/__init__.py in listdir(self, remotepath)
#     590         """
#     591         self._sftp_connect()
# --> 592         return sorted(self._sftp.listdir(remotepath))
#     593
#     594     def listdir_attr(self, remotepath='.'):
#
# /usr/local/lib/python3.7/dist-packages/paramiko/sftp_client.py in listdir(self, path)
#     216         :param str path: path to list (defaults to ``'.'``)
#     217         """
# --> 218         return [f.filename for f in self.listdir_attr(path)]
#     219
#     220     def listdir_attr(self, path="."):
#
# /usr/local/lib/python3.7/dist-packages/paramiko/sftp_client.py in listdir_attr(self, path)
#     237         path = self._adjust_cwd(path)
#     238         self._log(DEBUG, "listdir({!r})".format(path))
# --> 239         t, msg = self._request(CMD_OPENDIR, path)
#     240         if t != CMD_HANDLE:
#     241             raise SFTPError("Expected handle")
#
# /usr/local/lib/python3.7/dist-packages/paramiko/sftp_client.py in _request(self, t, *arg)
#     819
#     820     def _request(self, t, *arg):
# --> 821         num = self._async_request(type(None), t, *arg)
#     822         return self._read_response(num)
#     823
#
# /usr/local/lib/python3.7/dist-packages/paramiko/sftp_client.py in _async_request(self, fileobj, t, *arg)
#     844         finally:
#     845             self._lock.release()
# --> 846         self._send_packet(t, msg)
#     847         return num
#     848
#
# /usr/local/lib/python3.7/dist-packages/paramiko/sftp.py in _send_packet(self, t, packet)
#     196         if self.ultra_debug:
#     197             self._log(DEBUG, util.format_binary(out, "OUT: "))
# --> 198         self._write_all(out)
#     199
#     200     def _read_packet(self):
#
# /usr/local/lib/python3.7/dist-packages/paramiko/sftp.py in _write_all(self, out)
#     160     def _write_all(self, out):
#     161         while len(out) > 0:
# --> 162             n = self.sock.send(out)
#     163             if n <= 0:
#     164                 raise EOFError()
#
# /usr/local/lib/python3.7/dist-packages/paramiko/channel.py in send(self, s)
#     799         m.add_byte(cMSG_CHANNEL_DATA)
#     800         m.add_int(self.remote_chanid)
# --> 801         return self._send(s, m)
#     802
#     803     def send_stderr(self, s):
#
# /usr/local/lib/python3.7/dist-packages/paramiko/channel.py in _send(self, s, m)
#    1196                 # this doesn't seem useful, but it is the documented behavior
#    1197                 # of Socket
# -> 1198                 raise socket.error("Socket is closed")
#    1199             size = self._wait_for_send_window(size)
#    1200             if size == 0:
#
# OSError: Socket is closed

# %% [markdown]
# ### Beispiel Daten Intraday Trades German Market 01.01.2021

# %%
data = pd.read_csv("data/intradaydata_DE__2021-01-01.csv", dtype={'Date': 'str', 'Market Area Buy': 'str', 'Market Area Sell': 'str', 'Hour from': 'str', 'Hour to': 'str', 'Quantity (MW)': float, 'Price (EUR)': float, 'Time Stamp': 'str', 'Trade ID': 'str'}, skiprows=[0], parse_dates=["Date", "Time Stamp"])

# %%
# Choose data for Product Hour 8
data = data[data["Hour from"]=="8"]

# %%
# Remove unnecessary columns
# Date, Price and Time Stamp are needed
data = data[['Date', 'Price (EUR)', "Time Stamp"]]

# %%
# Rename Price column
data = data.rename(columns={'Price (EUR)': 'Price'})

# %%
data.head()
# Out:
#           Date  Price          Time Stamp
# 192 2021-01-01  31.36 2020-12-31 17:02:16
# 335 2021-01-01  39.65 2020-12-31 17:20:54
# 336 2021-01-01  42.50 2020-12-31 17:21:12
# 381 2021-01-01  42.00 2020-12-31 17:28:46
# 686 2021-01-01  39.45 2020-12-31 18:01:16

# %% [markdown]
# ## Lag Features Time Series Data

# %%
# Create Input Feature for T+1
dataframe = pd.concat([data["Price"].shift(1), data["Price"]], axis = 1)
dataframe.columns = ["t", "t+1"]

# %%
dataframe.head()
# Out:
#          t    t+1
# 192    NaN  31.36
# 335  31.36  39.65
# 336  39.65  42.50
# 381  42.50  42.00
# 686  42.00  39.45

# %%
# Create more Input Features with Lag
dataframe = pd.concat([data["Price"].shift(3), data["Price"].shift(2), data["Price"].shift(1), data["Price"]], axis = 1)
dataframe.columns = ["t-2", "t-1", "t", "t+1"]

# %%
dataframe.head()
# Out:
#        t-2    t-1      t    t+1
# 192    NaN    NaN    NaN  31.36
# 335    NaN    NaN  31.36  39.65
# 336    NaN  31.36  39.65  42.50
# 381  31.36  39.65  42.50  42.00
# 686  39.65  42.50  42.00  39.45

# %% [markdown]
# ## Rolling Window Statistics

# %%
# Create Mean of last 2 time steps as new input feature
prices = data["Price"]
shifted = prices.shift(1)
window = shifted.rolling(window=2)
means = window.mean()

# %%
dataframe = pd.concat([means, prices], axis = 1)
dataframe.columns = ["means(t-1, t)", "t+1"]

# %%
dataframe.head()
# Out:
#      means(t-1, t)    t+1
# 192            NaN  31.36
# 335            NaN  39.65
# 336         35.505  42.50
# 381         41.075  42.00
# 686         42.250  39.45

# %%
# Use Min, Mean and Max Value of last 3 time steps as input feature
prices = data["Price"]
width = 3
shifted = prices.shift(width - 1)
window = shifted.rolling(window=width)

# %%
dataframe = pd.concat([window.min(), window.mean(), window.max(), prices], axis = 1)
dataframe.columns = ["min", "mean", "max", "t+1"]

# %%
dataframe.head()
# Out:
#        min       mean   max    t+1
# 192    NaN        NaN   NaN  31.36
# 335    NaN        NaN   NaN  39.65
# 336    NaN        NaN   NaN  42.50
# 381    NaN        NaN   NaN  42.00
# 686  31.36  37.836667  42.5  39.45

# %% [markdown]
# ## Expanding Window Statistics

# %%
prices = data["Price"]
window = prices.expanding()
dataframe = pd.concat([window.min(), window.mean(), window.max(), prices.shift(-1)], axis = 1)
dataframe.columns = ["min", "mean", "max", "t+1"]

# %%
dataframe.head()
# Out:
#        min       mean    max    t+1
# 192  31.36  31.360000  31.36  39.65
# 335  31.36  35.505000  39.65  42.50
# 336  31.36  37.836667  42.50  42.00
# 381  31.36  38.877500  42.50  39.45
# 686  31.36  38.992000  42.50  39.45

# %% [markdown]
# # Moving Average Smoothing

# %%
# Use Moving Average as Input Feature
prices = data["Price"]
width = 3
lag1 = prices.shift(1)
lag3 = prices.shift(width-1)
window = lag3.rolling(window=width)
means = window.mean()
dataframe = pd.concat([means, lag1, prices], axis = 1)
dataframe.columns = ["mean", "t", "t+1"]

# %%
dataframe.head()
# Out:
#           mean      t    t+1
# 192        NaN    NaN  31.36
# 335        NaN  31.36  39.65
# 336        NaN  39.65  42.50
# 381        NaN  42.50  42.00
# 686  37.836667  42.00  39.45

# %% [markdown]
# ## Moving Average as Prediction

# %%
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot
from numpy import mean
from math import sqrt

# %%
# Use Moving Average Method as Time Series Prediction Method
X = data["Price"].values
window = 3
history = [X[i] for i in range(window)]
test = [X[i] for i in range(window, len(X))]
predictions = []

# walk forward over time steps in test

for t in range(len(test)):
  length = len(history)
  yhat = mean([history[i] for i in range(length-window, length)])
  obs = test[t]

  predictions.append(yhat)
  history.append(obs)

  print("predicted= %f, expected= %f" % (yhat, obs))


rmse = sqrt(mean_squared_error(test, predictions))

print("Test RMSE: %.3f" % rmse)
# Out:
# predicted= 37.836667, expected= 42.000000
# predicted= 41.383333, expected= 39.450000
# predicted= 41.316667, expected= 39.450000
# predicted= 40.300000, expected= 39.450000
# predicted= 39.450000, expected= 39.500000
# predicted= 39.466667, expected= 40.750000
# predicted= 39.900000, expected= 40.300000
# predicted= 40.183333, expected= 39.900000
# predicted= 40.316667, expected= 39.400000
# predicted= 39.866667, expected= 39.990000
# predicted= 39.763333, expected= 39.870000
# predicted= 39.753333, expected= 39.750000
# predicted= 39.870000, expected= 39.000000
# predicted= 39.540000, expected= 39.000000
# predicted= 39.250000, expected= 39.990000
# predicted= 39.330000, expected= 40.440000
# predicted= 39.810000, expected= 40.660000
# predicted= 40.363333, expected= 40.660000
# predicted= 40.586667, expected= 39.700000
# predicted= 40.340000, expected= 39.650000
# predicted= 40.003333, expected= 39.650000
# predicted= 39.666667, expected= 39.650000
# predicted= 39.650000, expected= 39.650000
# predicted= 39.650000, expected= 40.480000
# predicted= 39.926667, expected= 40.690000
# predicted= 40.273333, expected= 41.000000
# predicted= 40.723333, expected= 41.100000
# predicted= 40.930000, expected= 41.620000
# predicted= 41.240000, expected= 41.620000
# predicted= 41.446667, expected= 41.620000
# predicted= 41.620000, expected= 40.090000
# predicted= 41.110000, expected= 40.090000
# predicted= 40.600000, expected= 40.600000
# predicted= 40.260000, expected= 41.500000
# predicted= 40.730000, expected= 41.500000
# predicted= 41.200000, expected= 41.750000
# predicted= 41.583333, expected= 41.850000
# predicted= 41.700000, expected= 41.890000
# predicted= 41.830000, expected= 41.890000
# predicted= 41.876667, expected= 40.510000
# predicted= 41.430000, expected= 40.510000
# predicted= 40.970000, expected= 41.260000
# predicted= 40.760000, expected= 42.150000
# predicted= 41.306667, expected= 41.230000
# predicted= 41.546667, expected= 42.240000
# predicted= 41.873333, expected= 42.300000
# predicted= 41.923333, expected= 42.380000
# predicted= 42.306667, expected= 42.650000
# predicted= 42.443333, expected= 42.750000
# predicted= 42.593333, expected= 42.810000
# predicted= 42.736667, expected= 42.810000
# predicted= 42.790000, expected= 40.770000
# predicted= 42.130000, expected= 40.950000
# predicted= 41.510000, expected= 40.650000
# predicted= 40.790000, expected= 40.440000
# predicted= 40.680000, expected= 40.440000
# predicted= 40.510000, expected= 40.150000
# predicted= 40.343333, expected= 40.430000
# predicted= 40.340000, expected= 40.430000
# predicted= 40.336667, expected= 40.510000
# predicted= 40.456667, expected= 41.050000
# predicted= 40.663333, expected= 41.260000
# predicted= 40.940000, expected= 41.460000
# predicted= 41.256667, expected= 41.260000
# predicted= 41.326667, expected= 41.300000
# predicted= 41.340000, expected= 41.260000
# predicted= 41.273333, expected= 41.210000
# predicted= 41.256667, expected= 41.300000
# predicted= 41.256667, expected= 41.270000
# predicted= 41.260000, expected= 41.460000
# predicted= 41.343333, expected= 42.400000
# predicted= 41.710000, expected= 42.400000
# predicted= 42.086667, expected= 42.400000
# predicted= 42.400000, expected= 42.500000
# predicted= 42.433333, expected= 42.540000
# predicted= 42.480000, expected= 42.750000
# predicted= 42.596667, expected= 42.780000
# predicted= 42.690000, expected= 41.500000
# predicted= 42.343333, expected= 41.500000
# predicted= 41.926667, expected= 41.500000
# predicted= 41.500000, expected= 41.500000
# predicted= 41.500000, expected= 41.100000
# predicted= 41.366667, expected= 41.070000
# predicted= 41.223333, expected= 41.050000
# predicted= 41.073333, expected= 41.050000
# predicted= 41.056667, expected= 41.050000
# predicted= 41.050000, expected= 41.050000
# predicted= 41.050000, expected= 41.050000
# predicted= 41.050000, expected= 41.030000
# predicted= 41.043333, expected= 41.030000
# predicted= 41.036667, expected= 41.000000
# predicted= 41.020000, expected= 41.000000
# predicted= 41.010000, expected= 41.000000
# predicted= 41.000000, expected= 40.520000
# predicted= 40.840000, expected= 40.520000
# predicted= 40.680000, expected= 40.530000
# predicted= 40.523333, expected= 40.530000
# predicted= 40.526667, expected= 40.530000
# predicted= 40.530000, expected= 40.530000
# predicted= 40.530000, expected= 40.520000
# predicted= 40.526667, expected= 40.510000
# predicted= 40.520000, expected= 40.510000
# predicted= 40.513333, expected= 40.500000
# predicted= 40.506667, expected= 40.120000
# predicted= 40.376667, expected= 40.100000
# predicted= 40.240000, expected= 40.100000
# predicted= 40.106667, expected= 41.050000
# predicted= 40.416667, expected= 40.950000
# predicted= 40.700000, expected= 40.950000
# predicted= 40.983333, expected= 41.020000
# predicted= 40.973333, expected= 41.040000
# predicted= 41.003333, expected= 41.040000
# predicted= 41.033333, expected= 41.100000
# predicted= 41.060000, expected= 41.190000
# predicted= 41.110000, expected= 41.200000
# predicted= 41.163333, expected= 41.200000
# predicted= 41.196667, expected= 41.200000
# predicted= 41.200000, expected= 41.290000
# predicted= 41.230000, expected= 41.330000
# predicted= 41.273333, expected= 41.100000
# predicted= 41.240000, expected= 41.180000
# predicted= 41.203333, expected= 41.180000
# predicted= 41.153333, expected= 41.200000
# predicted= 41.186667, expected= 41.470000
# predicted= 41.283333, expected= 41.320000
# predicted= 41.330000, expected= 41.260000
# predicted= 41.350000, expected= 41.260000
# predicted= 41.280000, expected= 41.420000
# predicted= 41.313333, expected= 41.470000
# predicted= 41.383333, expected= 42.370000
# predicted= 41.753333, expected= 41.660000
# predicted= 41.833333, expected= 42.200000
# predicted= 42.076667, expected= 42.190000
# predicted= 42.016667, expected= 42.190000
# predicted= 42.193333, expected= 42.200000
# predicted= 42.193333, expected= 42.200000
# predicted= 42.196667, expected= 42.200000
# predicted= 42.200000, expected= 42.200000
# predicted= 42.200000, expected= 42.200000
# predicted= 42.200000, expected= 42.300000
# predicted= 42.233333, expected= 42.230000
# predicted= 42.243333, expected= 42.430000
# predicted= 42.320000, expected= 42.430000
# predicted= 42.363333, expected= 42.440000
# predicted= 42.433333, expected= 42.570000
# predicted= 42.480000, expected= 42.700000
# predicted= 42.570000, expected= 42.750000
# predicted= 42.673333, expected= 42.870000
# predicted= 42.773333, expected= 42.280000
# predicted= 42.633333, expected= 42.340000
# predicted= 42.496667, expected= 42.260000
# predicted= 42.293333, expected= 42.400000
# predicted= 42.333333, expected= 42.330000
# predicted= 42.330000, expected= 42.330000
# predicted= 42.353333, expected= 42.330000
# predicted= 42.330000, expected= 42.330000
# predicted= 42.330000, expected= 42.330000
# predicted= 42.330000, expected= 42.330000
# predicted= 42.330000, expected= 42.330000
# predicted= 42.330000, expected= 42.330000
# predicted= 42.330000, expected= 42.330000
# predicted= 42.330000, expected= 42.330000
# predicted= 42.330000, expected= 42.100000
# predicted= 42.253333, expected= 42.100000
# predicted= 42.176667, expected= 42.020000
# predicted= 42.073333, expected= 42.020000
# predicted= 42.046667, expected= 42.100000
# predicted= 42.046667, expected= 42.100000
# predicted= 42.073333, expected= 42.100000
# predicted= 42.100000, expected= 42.110000
# predicted= 42.103333, expected= 42.120000
# predicted= 42.110000, expected= 42.170000
# predicted= 42.133333, expected= 42.200000
# predicted= 42.163333, expected= 42.380000
# predicted= 42.250000, expected= 42.390000
# predicted= 42.323333, expected= 42.400000
# predicted= 42.390000, expected= 42.500000
# predicted= 42.430000, expected= 42.200000
# predicted= 42.366667, expected= 42.370000
# predicted= 42.356667, expected= 42.020000
# predicted= 42.196667, expected= 42.020000
# predicted= 42.136667, expected= 42.350000
# predicted= 42.130000, expected= 42.730000
# predicted= 42.366667, expected= 42.800000
# predicted= 42.626667, expected= 42.990000
# predicted= 42.840000, expected= 43.000000
# predicted= 42.930000, expected= 43.300000
# predicted= 43.096667, expected= 43.300000
# predicted= 43.200000, expected= 43.300000
# predicted= 43.300000, expected= 43.300000
# predicted= 43.300000, expected= 43.030000
# predicted= 43.210000, expected= 43.200000
# predicted= 43.176667, expected= 43.290000
# predicted= 43.173333, expected= 43.300000
# predicted= 43.263333, expected= 43.500000
# predicted= 43.363333, expected= 43.130000
# predicted= 43.310000, expected= 43.150000
# predicted= 43.260000, expected= 43.300000
# predicted= 43.193333, expected= 43.360000
# predicted= 43.270000, expected= 43.460000
# predicted= 43.373333, expected= 43.510000
# predicted= 43.443333, expected= 43.510000
# predicted= 43.493333, expected= 43.790000
# predicted= 43.603333, expected= 43.800000
# predicted= 43.700000, expected= 43.540000
# predicted= 43.710000, expected= 43.610000
# predicted= 43.650000, expected= 43.620000
# predicted= 43.590000, expected= 43.610000
# predicted= 43.613333, expected= 43.800000
# predicted= 43.676667, expected= 43.660000
# predicted= 43.690000, expected= 43.890000
# predicted= 43.783333, expected= 43.900000
# predicted= 43.816667, expected= 43.900000
# predicted= 43.896667, expected= 43.540000
# predicted= 43.780000, expected= 43.520000
# predicted= 43.653333, expected= 43.790000
# predicted= 43.616667, expected= 43.690000
# predicted= 43.666667, expected= 43.690000
# predicted= 43.723333, expected= 43.000000
# predicted= 43.460000, expected= 43.000000
# predicted= 43.230000, expected= 43.000000
# predicted= 43.000000, expected= 42.990000
# predicted= 42.996667, expected= 43.000000
# predicted= 42.996667, expected= 43.000000
# predicted= 42.996667, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.340000
# predicted= 43.113333, expected= 43.340000
# predicted= 43.226667, expected= 43.740000
# predicted= 43.473333, expected= 44.000000
# predicted= 43.693333, expected= 44.150000
# predicted= 43.963333, expected= 44.300000
# predicted= 44.150000, expected= 44.300000
# predicted= 44.250000, expected= 44.300000
# predicted= 44.300000, expected= 44.400000
# predicted= 44.333333, expected= 44.400000
# predicted= 44.366667, expected= 44.500000
# predicted= 44.433333, expected= 44.500000
# predicted= 44.466667, expected= 44.500000
# predicted= 44.500000, expected= 44.500000
# predicted= 44.500000, expected= 44.600000
# predicted= 44.533333, expected= 44.650000
# predicted= 44.583333, expected= 44.740000
# predicted= 44.663333, expected= 44.740000
# predicted= 44.710000, expected= 44.740000
# predicted= 44.740000, expected= 44.720000
# predicted= 44.733333, expected= 44.760000
# predicted= 44.740000, expected= 44.500000
# predicted= 44.660000, expected= 44.500000
# predicted= 44.586667, expected= 44.300000
# predicted= 44.433333, expected= 44.300000
# predicted= 44.366667, expected= 44.300000
# predicted= 44.300000, expected= 44.320000
# predicted= 44.306667, expected= 44.330000
# predicted= 44.316667, expected= 44.500000
# predicted= 44.383333, expected= 44.520000
# predicted= 44.450000, expected= 44.520000
# predicted= 44.513333, expected= 44.520000
# predicted= 44.520000, expected= 44.630000
# predicted= 44.556667, expected= 44.630000
# predicted= 44.593333, expected= 44.630000
# predicted= 44.630000, expected= 44.520000
# predicted= 44.593333, expected= 44.520000
# predicted= 44.556667, expected= 44.520000
# predicted= 44.520000, expected= 44.520000
# predicted= 44.520000, expected= 44.520000
# predicted= 44.520000, expected= 44.520000
# predicted= 44.520000, expected= 44.520000
# predicted= 44.520000, expected= 44.520000
# predicted= 44.520000, expected= 44.520000
# predicted= 44.520000, expected= 44.500000
# predicted= 44.513333, expected= 44.500000
# predicted= 44.506667, expected= 44.500000
# predicted= 44.500000, expected= 43.230000
# predicted= 44.076667, expected= 43.220000
# predicted= 43.650000, expected= 43.220000
# predicted= 43.223333, expected= 43.220000
# predicted= 43.220000, expected= 43.230000
# predicted= 43.223333, expected= 43.230000
# predicted= 43.226667, expected= 43.890000
# predicted= 43.450000, expected= 43.900000
# predicted= 43.673333, expected= 43.840000
# predicted= 43.876667, expected= 43.540000
# predicted= 43.760000, expected= 42.770000
# predicted= 43.383333, expected= 42.800000
# predicted= 43.036667, expected= 42.800000
# predicted= 42.790000, expected= 42.690000
# predicted= 42.763333, expected= 43.100000
# predicted= 42.863333, expected= 43.100000
# predicted= 42.963333, expected= 43.100000
# predicted= 43.100000, expected= 43.110000
# predicted= 43.103333, expected= 43.130000
# predicted= 43.113333, expected= 43.130000
# predicted= 43.123333, expected= 43.130000
# predicted= 43.130000, expected= 43.130000
# predicted= 43.130000, expected= 43.130000
# predicted= 43.130000, expected= 43.140000
# predicted= 43.133333, expected= 43.000000
# predicted= 43.090000, expected= 43.020000
# predicted= 43.053333, expected= 43.020000
# predicted= 43.013333, expected= 43.100000
# predicted= 43.046667, expected= 43.020000
# predicted= 43.046667, expected= 43.000000
# predicted= 43.040000, expected= 43.200000
# predicted= 43.073333, expected= 43.300000
# predicted= 43.166667, expected= 43.320000
# predicted= 43.273333, expected= 43.340000
# predicted= 43.320000, expected= 43.340000
# predicted= 43.333333, expected= 43.340000
# predicted= 43.340000, expected= 43.350000
# predicted= 43.343333, expected= 43.300000
# predicted= 43.330000, expected= 43.350000
# predicted= 43.333333, expected= 43.350000
# predicted= 43.333333, expected= 43.460000
# predicted= 43.386667, expected= 43.340000
# predicted= 43.383333, expected= 43.480000
# predicted= 43.426667, expected= 44.200000
# predicted= 43.673333, expected= 43.000000
# predicted= 43.560000, expected= 43.000000
# predicted= 43.400000, expected= 43.230000
# predicted= 43.076667, expected= 43.230000
# predicted= 43.153333, expected= 43.230000
# predicted= 43.230000, expected= 43.230000
# predicted= 43.230000, expected= 43.230000
# predicted= 43.230000, expected= 43.310000
# predicted= 43.256667, expected= 43.000000
# predicted= 43.180000, expected= 43.000000
# predicted= 43.103333, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.020000
# predicted= 43.006667, expected= 43.020000
# predicted= 43.013333, expected= 43.000000
# predicted= 43.013333, expected= 43.000000
# predicted= 43.006667, expected= 43.000000
# predicted= 43.000000, expected= 43.130000
# predicted= 43.043333, expected= 43.140000
# predicted= 43.090000, expected= 43.140000
# predicted= 43.136667, expected= 43.140000
# predicted= 43.140000, expected= 43.150000
# predicted= 43.143333, expected= 43.000000
# predicted= 43.096667, expected= 43.150000
# predicted= 43.100000, expected= 43.000000
# predicted= 43.050000, expected= 43.000000
# predicted= 43.050000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.110000
# predicted= 43.036667, expected= 43.110000
# predicted= 43.073333, expected= 43.070000
# predicted= 43.096667, expected= 43.070000
# predicted= 43.083333, expected= 43.070000
# predicted= 43.070000, expected= 43.070000
# predicted= 43.070000, expected= 43.070000
# predicted= 43.070000, expected= 43.070000
# predicted= 43.070000, expected= 43.060000
# predicted= 43.066667, expected= 43.060000
# predicted= 43.063333, expected= 43.060000
# predicted= 43.060000, expected= 43.050000
# predicted= 43.056667, expected= 43.050000
# predicted= 43.053333, expected= 43.050000
# predicted= 43.050000, expected= 43.020000
# predicted= 43.040000, expected= 43.020000
# predicted= 43.030000, expected= 43.020000
# predicted= 43.020000, expected= 43.020000
# predicted= 43.020000, expected= 43.020000
# predicted= 43.020000, expected= 43.020000
# predicted= 43.020000, expected= 43.020000
# predicted= 43.020000, expected= 43.020000
# predicted= 43.020000, expected= 43.020000
# predicted= 43.020000, expected= 43.010000
# predicted= 43.016667, expected= 43.030000
# predicted= 43.020000, expected= 43.030000
# predicted= 43.023333, expected= 43.000000
# predicted= 43.020000, expected= 43.000000
# predicted= 43.010000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.030000
# predicted= 43.010000, expected= 43.240000
# predicted= 43.090000, expected= 43.020000
# predicted= 43.096667, expected= 43.020000
# predicted= 43.093333, expected= 43.020000
# predicted= 43.020000, expected= 43.020000
# predicted= 43.020000, expected= 43.000000
# predicted= 43.013333, expected= 43.000000
# predicted= 43.006667, expected= 43.250000
# predicted= 43.083333, expected= 43.020000
# predicted= 43.090000, expected= 43.000000
# predicted= 43.090000, expected= 43.000000
# predicted= 43.006667, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.020000
# predicted= 43.006667, expected= 43.000000
# predicted= 43.006667, expected= 43.000000
# predicted= 43.006667, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.050000
# predicted= 43.016667, expected= 43.000000
# predicted= 43.016667, expected= 43.000000
# predicted= 43.016667, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.010000
# predicted= 43.003333, expected= 43.000000
# predicted= 43.003333, expected= 43.000000
# predicted= 43.003333, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 43.000000
# predicted= 43.000000, expected= 41.990000
# predicted= 42.663333, expected= 42.200000
# predicted= 42.396667, expected= 42.200000
# predicted= 42.130000, expected= 41.990000
# predicted= 42.130000, expected= 42.150000
# predicted= 42.113333, expected= 41.800000
# predicted= 41.980000, expected= 41.750000
# predicted= 41.900000, expected= 41.720000
# predicted= 41.756667, expected= 41.720000
# predicted= 41.730000, expected= 41.720000
# predicted= 41.720000, expected= 41.720000
# predicted= 41.720000, expected= 41.520000
# predicted= 41.653333, expected= 41.680000
# predicted= 41.640000, expected= 41.600000
# predicted= 41.600000, expected= 41.530000
# predicted= 41.603333, expected= 41.520000
# predicted= 41.550000, expected= 41.510000
# predicted= 41.520000, expected= 41.500000
# predicted= 41.510000, expected= 41.500000
# predicted= 41.503333, expected= 41.500000
# predicted= 41.500000, expected= 41.500000
# predicted= 41.500000, expected= 41.370000
# predicted= 41.456667, expected= 41.400000
# predicted= 41.423333, expected= 41.300000
# predicted= 41.356667, expected= 41.260000
# predicted= 41.320000, expected= 41.250000
# predicted= 41.270000, expected= 41.000000
# predicted= 41.170000, expected= 41.020000
# predicted= 41.090000, expected= 41.020000
# predicted= 41.013333, expected= 41.160000
# predicted= 41.066667, expected= 41.160000
# predicted= 41.113333, expected= 41.020000
# predicted= 41.113333, expected= 41.000000
# predicted= 41.060000, expected= 41.200000
# predicted= 41.073333, expected= 41.000000
# predicted= 41.066667, expected= 41.000000
# predicted= 41.066667, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.100000
# predicted= 41.033333, expected= 41.000000
# predicted= 41.033333, expected= 41.100000
# predicted= 41.066667, expected= 41.000000
# predicted= 41.033333, expected= 41.190000
# predicted= 41.096667, expected= 41.140000
# predicted= 41.110000, expected= 41.000000
# predicted= 41.110000, expected= 41.000000
# predicted= 41.046667, expected= 41.010000
# predicted= 41.003333, expected= 41.000000
# predicted= 41.003333, expected= 41.000000
# predicted= 41.003333, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 40.960000
# predicted= 40.986667, expected= 41.000000
# predicted= 40.986667, expected= 41.000000
# predicted= 40.986667, expected= 41.000000
# predicted= 41.000000, expected= 40.770000
# predicted= 40.923333, expected= 40.750000
# predicted= 40.840000, expected= 40.630000
# predicted= 40.716667, expected= 40.630000
# predicted= 40.670000, expected= 40.600000
# predicted= 40.620000, expected= 40.560000
# predicted= 40.596667, expected= 40.090000
# predicted= 40.416667, expected= 40.360000
# predicted= 40.336667, expected= 40.330000
# predicted= 40.260000, expected= 40.290000
# predicted= 40.326667, expected= 40.330000
# predicted= 40.316667, expected= 40.250000
# predicted= 40.290000, expected= 40.260000
# predicted= 40.280000, expected= 40.180000
# predicted= 40.230000, expected= 40.170000
# predicted= 40.203333, expected= 40.090000
# predicted= 40.146667, expected= 40.100000
# predicted= 40.120000, expected= 40.100000
# predicted= 40.096667, expected= 40.100000
# predicted= 40.100000, expected= 40.100000
# predicted= 40.100000, expected= 40.100000
# predicted= 40.100000, expected= 40.120000
# predicted= 40.106667, expected= 40.100000
# predicted= 40.106667, expected= 40.090000
# predicted= 40.103333, expected= 40.160000
# predicted= 40.116667, expected= 40.150000
# predicted= 40.133333, expected= 40.090000
# predicted= 40.133333, expected= 40.090000
# predicted= 40.110000, expected= 40.090000
# predicted= 40.090000, expected= 40.000000
# predicted= 40.060000, expected= 40.000000
# predicted= 40.030000, expected= 40.000000
# predicted= 40.000000, expected= 39.910000
# predicted= 39.970000, expected= 39.800000
# predicted= 39.903333, expected= 39.700000
# predicted= 39.803333, expected= 39.700000
# predicted= 39.733333, expected= 39.700000
# predicted= 39.700000, expected= 39.700000
# predicted= 39.700000, expected= 39.700000
# predicted= 39.700000, expected= 39.700000
# predicted= 39.700000, expected= 39.660000
# predicted= 39.686667, expected= 39.630000
# predicted= 39.663333, expected= 39.630000
# predicted= 39.640000, expected= 39.630000
# predicted= 39.630000, expected= 39.630000
# predicted= 39.630000, expected= 39.590000
# predicted= 39.616667, expected= 39.590000
# predicted= 39.603333, expected= 39.590000
# predicted= 39.590000, expected= 39.590000
# predicted= 39.590000, expected= 39.590000
# predicted= 39.590000, expected= 39.590000
# predicted= 39.590000, expected= 39.590000
# predicted= 39.590000, expected= 39.580000
# predicted= 39.586667, expected= 39.350000
# predicted= 39.506667, expected= 39.440000
# predicted= 39.456667, expected= 39.440000
# predicted= 39.410000, expected= 39.400000
# predicted= 39.426667, expected= 39.280000
# predicted= 39.373333, expected= 39.280000
# predicted= 39.320000, expected= 39.330000
# predicted= 39.296667, expected= 39.330000
# predicted= 39.313333, expected= 39.280000
# predicted= 39.313333, expected= 39.270000
# predicted= 39.293333, expected= 39.260000
# predicted= 39.270000, expected= 39.160000
# predicted= 39.230000, expected= 39.160000
# predicted= 39.193333, expected= 39.160000
# predicted= 39.160000, expected= 39.260000
# predicted= 39.193333, expected= 39.130000
# predicted= 39.183333, expected= 39.110000
# predicted= 39.166667, expected= 39.280000
# predicted= 39.173333, expected= 39.280000
# predicted= 39.223333, expected= 39.280000
# predicted= 39.280000, expected= 39.130000
# predicted= 39.230000, expected= 39.310000
# predicted= 39.240000, expected= 39.310000
# predicted= 39.250000, expected= 39.440000
# predicted= 39.353333, expected= 39.460000
# predicted= 39.403333, expected= 39.470000
# predicted= 39.456667, expected= 39.210000
# predicted= 39.380000, expected= 39.400000
# predicted= 39.360000, expected= 39.390000
# predicted= 39.333333, expected= 39.450000
# predicted= 39.413333, expected= 39.450000
# predicted= 39.430000, expected= 39.470000
# predicted= 39.456667, expected= 39.470000
# predicted= 39.463333, expected= 39.470000
# predicted= 39.470000, expected= 40.000000
# predicted= 39.646667, expected= 40.000000
# predicted= 39.823333, expected= 40.110000
# predicted= 40.036667, expected= 39.450000
# predicted= 39.853333, expected= 39.450000
# predicted= 39.670000, expected= 39.450000
# predicted= 39.450000, expected= 39.450000
# predicted= 39.450000, expected= 39.540000
# predicted= 39.480000, expected= 39.540000
# predicted= 39.510000, expected= 39.530000
# predicted= 39.536667, expected= 39.530000
# predicted= 39.533333, expected= 39.540000
# predicted= 39.533333, expected= 39.610000
# predicted= 39.560000, expected= 40.000000
# predicted= 39.716667, expected= 40.110000
# predicted= 39.906667, expected= 40.100000
# predicted= 40.070000, expected= 39.570000
# predicted= 39.926667, expected= 39.570000
# predicted= 39.746667, expected= 39.660000
# predicted= 39.600000, expected= 39.660000
# predicted= 39.630000, expected= 39.670000
# predicted= 39.663333, expected= 39.670000
# predicted= 39.666667, expected= 40.100000
# predicted= 39.813333, expected= 40.850000
# predicted= 40.206667, expected= 41.050000
# predicted= 40.666667, expected= 40.650000
# predicted= 40.850000, expected= 40.650000
# predicted= 40.783333, expected= 39.890000
# predicted= 40.396667, expected= 40.570000
# predicted= 40.370000, expected= 40.090000
# predicted= 40.183333, expected= 40.060000
# predicted= 40.240000, expected= 40.060000
# predicted= 40.070000, expected= 40.060000
# predicted= 40.060000, expected= 40.060000
# predicted= 40.060000, expected= 39.940000
# predicted= 40.020000, expected= 39.940000
# predicted= 39.980000, expected= 39.940000
# predicted= 39.940000, expected= 39.940000
# predicted= 39.940000, expected= 39.940000
# predicted= 39.940000, expected= 39.940000
# predicted= 39.940000, expected= 39.940000
# predicted= 39.940000, expected= 39.940000
# predicted= 39.940000, expected= 39.820000
# predicted= 39.900000, expected= 39.830000
# predicted= 39.863333, expected= 40.100000
# predicted= 39.916667, expected= 40.000000
# predicted= 39.976667, expected= 40.180000
# predicted= 40.093333, expected= 40.180000
# predicted= 40.120000, expected= 40.100000
# predicted= 40.153333, expected= 40.340000
# predicted= 40.206667, expected= 40.340000
# predicted= 40.260000, expected= 40.340000
# predicted= 40.340000, expected= 40.340000
# predicted= 40.340000, expected= 40.250000
# predicted= 40.310000, expected= 40.200000
# predicted= 40.263333, expected= 40.120000
# predicted= 40.190000, expected= 40.120000
# predicted= 40.146667, expected= 40.250000
# predicted= 40.163333, expected= 40.250000
# predicted= 40.206667, expected= 40.100000
# predicted= 40.200000, expected= 40.100000
# predicted= 40.150000, expected= 39.970000
# predicted= 40.056667, expected= 39.970000
# predicted= 40.013333, expected= 40.100000
# predicted= 40.013333, expected= 40.100000
# predicted= 40.056667, expected= 40.110000
# predicted= 40.103333, expected= 40.180000
# predicted= 40.130000, expected= 40.200000
# predicted= 40.163333, expected= 40.200000
# predicted= 40.193333, expected= 40.250000
# predicted= 40.216667, expected= 40.250000
# predicted= 40.233333, expected= 40.300000
# predicted= 40.266667, expected= 40.340000
# predicted= 40.296667, expected= 40.340000
# predicted= 40.326667, expected= 39.970000
# predicted= 40.216667, expected= 39.970000
# predicted= 40.093333, expected= 40.350000
# predicted= 40.096667, expected= 40.390000
# predicted= 40.236667, expected= 41.500000
# predicted= 40.746667, expected= 41.510000
# predicted= 41.133333, expected= 41.910000
# predicted= 41.640000, expected= 42.120000
# predicted= 41.846667, expected= 42.140000
# predicted= 42.056667, expected= 42.160000
# predicted= 42.140000, expected= 40.440000
# predicted= 41.580000, expected= 42.160000
# predicted= 41.586667, expected= 42.650000
# predicted= 41.750000, expected= 42.750000
# predicted= 42.520000, expected= 43.000000
# predicted= 42.800000, expected= 43.060000
# predicted= 42.936667, expected= 43.930000
# predicted= 43.330000, expected= 44.310000
# predicted= 43.766667, expected= 44.310000
# predicted= 44.183333, expected= 40.440000
# predicted= 43.020000, expected= 40.100000
# predicted= 41.616667, expected= 40.000000
# predicted= 40.180000, expected= 39.970000
# predicted= 40.023333, expected= 39.970000
# predicted= 39.980000, expected= 39.970000
# predicted= 39.970000, expected= 40.220000
# predicted= 40.053333, expected= 40.250000
# predicted= 40.146667, expected= 40.290000
# predicted= 40.253333, expected= 40.320000
# predicted= 40.286667, expected= 40.460000
# predicted= 40.356667, expected= 40.540000
# predicted= 40.440000, expected= 40.900000
# predicted= 40.633333, expected= 40.900000
# predicted= 40.780000, expected= 40.910000
# predicted= 40.903333, expected= 40.980000
# predicted= 40.930000, expected= 41.000000
# predicted= 40.963333, expected= 41.090000
# predicted= 41.023333, expected= 41.060000
# predicted= 41.050000, expected= 41.090000
# predicted= 41.080000, expected= 41.200000
# predicted= 41.116667, expected= 41.200000
# predicted= 41.163333, expected= 41.250000
# predicted= 41.216667, expected= 41.300000
# predicted= 41.250000, expected= 41.300000
# predicted= 41.283333, expected= 41.330000
# predicted= 41.310000, expected= 41.330000
# predicted= 41.320000, expected= 41.330000
# predicted= 41.330000, expected= 41.330000
# predicted= 41.330000, expected= 41.330000
# predicted= 41.330000, expected= 41.330000
# predicted= 41.330000, expected= 41.340000
# predicted= 41.333333, expected= 41.340000
# predicted= 41.336667, expected= 41.500000
# predicted= 41.393333, expected= 41.510000
# predicted= 41.450000, expected= 41.800000
# predicted= 41.603333, expected= 41.800000
# predicted= 41.703333, expected= 41.800000
# predicted= 41.800000, expected= 42.100000
# predicted= 41.900000, expected= 42.100000
# predicted= 42.000000, expected= 42.100000
# predicted= 42.100000, expected= 41.900000
# predicted= 42.033333, expected= 41.800000
# predicted= 41.933333, expected= 41.800000
# predicted= 41.833333, expected= 41.800000
# predicted= 41.800000, expected= 41.800000
# predicted= 41.800000, expected= 41.800000
# predicted= 41.800000, expected= 41.900000
# predicted= 41.833333, expected= 41.900000
# predicted= 41.866667, expected= 41.900000
# predicted= 41.900000, expected= 41.900000
# predicted= 41.900000, expected= 41.950000
# predicted= 41.916667, expected= 41.950000
# predicted= 41.933333, expected= 41.800000
# predicted= 41.900000, expected= 41.800000
# predicted= 41.850000, expected= 41.800000
# predicted= 41.800000, expected= 41.800000
# predicted= 41.800000, expected= 41.800000
# predicted= 41.800000, expected= 41.800000
# predicted= 41.800000, expected= 41.950000
# predicted= 41.850000, expected= 41.950000
# predicted= 41.900000, expected= 42.100000
# predicted= 42.000000, expected= 42.120000
# predicted= 42.056667, expected= 42.200000
# predicted= 42.140000, expected= 42.200000
# predicted= 42.173333, expected= 42.200000
# predicted= 42.200000, expected= 42.200000
# predicted= 42.200000, expected= 42.300000
# predicted= 42.233333, expected= 42.300000
# predicted= 42.266667, expected= 42.300000
# predicted= 42.300000, expected= 42.300000
# predicted= 42.300000, expected= 42.300000
# predicted= 42.300000, expected= 42.300000
# predicted= 42.300000, expected= 42.300000
# predicted= 42.300000, expected= 42.400000
# predicted= 42.333333, expected= 42.300000
# predicted= 42.333333, expected= 42.300000
# predicted= 42.333333, expected= 42.300000
# predicted= 42.300000, expected= 42.300000
# predicted= 42.300000, expected= 42.320000
# predicted= 42.306667, expected= 42.320000
# predicted= 42.313333, expected= 42.400000
# predicted= 42.346667, expected= 42.300000
# predicted= 42.340000, expected= 42.310000
# predicted= 42.336667, expected= 42.310000
# predicted= 42.306667, expected= 42.320000
# predicted= 42.313333, expected= 42.300000
# predicted= 42.310000, expected= 42.400000
# predicted= 42.340000, expected= 42.400000
# predicted= 42.366667, expected= 42.300000
# predicted= 42.366667, expected= 42.300000
# predicted= 42.333333, expected= 42.100000
# predicted= 42.233333, expected= 42.030000
# predicted= 42.143333, expected= 41.900000
# predicted= 42.010000, expected= 42.200000
# predicted= 42.043333, expected= 42.030000
# predicted= 42.043333, expected= 42.030000
# predicted= 42.086667, expected= 42.030000
# predicted= 42.030000, expected= 41.930000
# predicted= 41.996667, expected= 41.900000
# predicted= 41.953333, expected= 41.900000
# predicted= 41.910000, expected= 41.900000
# predicted= 41.900000, expected= 41.900000
# predicted= 41.900000, expected= 41.900000
# predicted= 41.900000, expected= 41.500000
# predicted= 41.766667, expected= 41.500000
# predicted= 41.633333, expected= 41.500000
# predicted= 41.500000, expected= 41.500000
# predicted= 41.500000, expected= 41.500000
# predicted= 41.500000, expected= 41.500000
# predicted= 41.500000, expected= 41.700000
# predicted= 41.566667, expected= 41.700000
# predicted= 41.633333, expected= 41.720000
# predicted= 41.706667, expected= 41.720000
# predicted= 41.713333, expected= 41.720000
# predicted= 41.720000, expected= 41.800000
# predicted= 41.746667, expected= 41.800000
# predicted= 41.773333, expected= 41.900000
# predicted= 41.833333, expected= 41.900000
# predicted= 41.866667, expected= 41.900000
# predicted= 41.900000, expected= 41.900000
# predicted= 41.900000, expected= 41.900000
# predicted= 41.900000, expected= 41.900000
# predicted= 41.900000, expected= 41.900000
# predicted= 41.900000, expected= 41.600000
# predicted= 41.800000, expected= 41.590000
# predicted= 41.696667, expected= 41.590000
# predicted= 41.593333, expected= 41.560000
# predicted= 41.580000, expected= 41.580000
# predicted= 41.576667, expected= 41.580000
# predicted= 41.573333, expected= 41.620000
# predicted= 41.593333, expected= 41.620000
# predicted= 41.606667, expected= 41.500000
# predicted= 41.580000, expected= 41.550000
# predicted= 41.556667, expected= 41.540000
# predicted= 41.530000, expected= 41.540000
# predicted= 41.543333, expected= 41.500000
# predicted= 41.526667, expected= 41.500000
# predicted= 41.513333, expected= 41.460000
# predicted= 41.486667, expected= 41.400000
# predicted= 41.453333, expected= 41.100000
# predicted= 41.320000, expected= 40.970000
# predicted= 41.156667, expected= 41.030000
# predicted= 41.033333, expected= 41.030000
# predicted= 41.010000, expected= 40.980000
# predicted= 41.013333, expected= 41.000000
# predicted= 41.003333, expected= 40.970000
# predicted= 40.983333, expected= 40.990000
# predicted= 40.986667, expected= 40.990000
# predicted= 40.983333, expected= 40.990000
# predicted= 40.990000, expected= 40.980000
# predicted= 40.986667, expected= 41.030000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.003333, expected= 41.000000
# predicted= 41.010000, expected= 41.030000
# predicted= 41.010000, expected= 41.030000
# predicted= 41.020000, expected= 41.030000
# predicted= 41.030000, expected= 41.100000
# predicted= 41.053333, expected= 41.100000
# predicted= 41.076667, expected= 41.030000
# predicted= 41.076667, expected= 41.030000
# predicted= 41.053333, expected= 41.030000
# predicted= 41.030000, expected= 41.110000
# predicted= 41.056667, expected= 41.110000
# predicted= 41.083333, expected= 41.030000
# predicted= 41.083333, expected= 41.030000
# predicted= 41.056667, expected= 41.030000
# predicted= 41.030000, expected= 41.120000
# predicted= 41.060000, expected= 41.070000
# predicted= 41.073333, expected= 41.070000
# predicted= 41.086667, expected= 41.120000
# predicted= 41.086667, expected= 41.120000
# predicted= 41.103333, expected= 41.490000
# predicted= 41.243333, expected= 41.500000
# predicted= 41.370000, expected= 41.500000
# predicted= 41.496667, expected= 41.500000
# predicted= 41.500000, expected= 41.620000
# predicted= 41.540000, expected= 41.900000
# predicted= 41.673333, expected= 41.910000
# predicted= 41.810000, expected= 42.000000
# predicted= 41.936667, expected= 42.000000
# predicted= 41.970000, expected= 42.000000
# predicted= 42.000000, expected= 42.000000
# predicted= 42.000000, expected= 42.000000
# predicted= 42.000000, expected= 42.000000
# predicted= 42.000000, expected= 42.000000
# predicted= 42.000000, expected= 42.000000
# predicted= 42.000000, expected= 42.000000
# predicted= 42.000000, expected= 42.000000
# predicted= 42.000000, expected= 42.070000
# predicted= 42.023333, expected= 42.000000
# predicted= 42.023333, expected= 42.000000
# predicted= 42.023333, expected= 42.070000
# predicted= 42.023333, expected= 42.000000
# predicted= 42.023333, expected= 41.900000
# predicted= 41.990000, expected= 41.830000
# predicted= 41.910000, expected= 41.830000
# predicted= 41.853333, expected= 41.750000
# predicted= 41.803333, expected= 41.750000
# predicted= 41.776667, expected= 41.750000
# predicted= 41.750000, expected= 41.700000
# predicted= 41.733333, expected= 41.750000
# predicted= 41.733333, expected= 41.750000
# predicted= 41.733333, expected= 41.600000
# predicted= 41.700000, expected= 42.000000
# predicted= 41.783333, expected= 41.700000
# predicted= 41.766667, expected= 41.700000
# predicted= 41.800000, expected= 41.600000
# predicted= 41.666667, expected= 41.300000
# predicted= 41.533333, expected= 41.300000
# predicted= 41.400000, expected= 41.690000
# predicted= 41.430000, expected= 41.300000
# predicted= 41.430000, expected= 41.230000
# predicted= 41.406667, expected= 41.230000
# predicted= 41.253333, expected= 41.220000
# predicted= 41.226667, expected= 41.200000
# predicted= 41.216667, expected= 41.200000
# predicted= 41.206667, expected= 41.200000
# predicted= 41.200000, expected= 41.200000
# predicted= 41.200000, expected= 41.200000
# predicted= 41.200000, expected= 41.300000
# predicted= 41.233333, expected= 41.200000
# predicted= 41.233333, expected= 41.200000
# predicted= 41.233333, expected= 41.200000
# predicted= 41.200000, expected= 41.200000
# predicted= 41.200000, expected= 41.000000
# predicted= 41.133333, expected= 41.000000
# predicted= 41.066667, expected= 40.980000
# predicted= 40.993333, expected= 40.980000
# predicted= 40.986667, expected= 40.970000
# predicted= 40.976667, expected= 40.800000
# predicted= 40.916667, expected= 40.700000
# predicted= 40.823333, expected= 40.700000
# predicted= 40.733333, expected= 40.020000
# predicted= 40.473333, expected= 41.190000
# predicted= 40.636667, expected= 40.900000
# predicted= 40.703333, expected= 41.180000
# predicted= 41.090000, expected= 40.400000
# predicted= 40.826667, expected= 40.300000
# predicted= 40.626667, expected= 40.120000
# predicted= 40.273333, expected= 40.100000
# predicted= 40.173333, expected= 40.020000
# predicted= 40.080000, expected= 40.100000
# predicted= 40.073333, expected= 40.100000
# predicted= 40.073333, expected= 40.410000
# predicted= 40.203333, expected= 40.410000
# predicted= 40.306667, expected= 40.400000
# predicted= 40.406667, expected= 40.390000
# predicted= 40.400000, expected= 40.410000
# predicted= 40.400000, expected= 40.300000
# predicted= 40.366667, expected= 40.300000
# predicted= 40.336667, expected= 40.290000
# predicted= 40.296667, expected= 40.290000
# predicted= 40.293333, expected= 40.280000
# predicted= 40.286667, expected= 40.270000
# predicted= 40.280000, expected= 40.270000
# predicted= 40.273333, expected= 40.270000
# predicted= 40.270000, expected= 40.290000
# predicted= 40.276667, expected= 40.300000
# predicted= 40.286667, expected= 40.300000
# predicted= 40.296667, expected= 40.400000
# predicted= 40.333333, expected= 40.400000
# predicted= 40.366667, expected= 40.400000
# predicted= 40.400000, expected= 40.500000
# predicted= 40.433333, expected= 40.510000
# predicted= 40.470000, expected= 40.510000
# predicted= 40.506667, expected= 40.510000
# predicted= 40.510000, expected= 40.510000
# predicted= 40.510000, expected= 40.510000
# predicted= 40.510000, expected= 40.700000
# predicted= 40.573333, expected= 40.700000
# predicted= 40.636667, expected= 40.700000
# predicted= 40.700000, expected= 40.700000
# predicted= 40.700000, expected= 40.800000
# predicted= 40.733333, expected= 40.750000
# predicted= 40.750000, expected= 40.750000
# predicted= 40.766667, expected= 40.750000
# predicted= 40.750000, expected= 40.750000
# predicted= 40.750000, expected= 40.750000
# predicted= 40.750000, expected= 40.750000
# predicted= 40.750000, expected= 40.750000
# predicted= 40.750000, expected= 40.750000
# predicted= 40.750000, expected= 40.750000
# predicted= 40.750000, expected= 40.750000
# predicted= 40.750000, expected= 40.750000
# predicted= 40.750000, expected= 40.750000
# predicted= 40.750000, expected= 41.100000
# predicted= 40.866667, expected= 41.100000
# predicted= 40.983333, expected= 40.930000
# predicted= 41.043333, expected= 40.930000
# predicted= 40.986667, expected= 41.300000
# predicted= 41.053333, expected= 41.700000
# predicted= 41.310000, expected= 41.130000
# predicted= 41.376667, expected= 41.130000
# predicted= 41.320000, expected= 41.300000
# predicted= 41.186667, expected= 41.800000
# predicted= 41.410000, expected= 41.800000
# predicted= 41.633333, expected= 41.340000
# predicted= 41.646667, expected= 41.340000
# predicted= 41.493333, expected= 41.340000
# predicted= 41.340000, expected= 41.340000
# predicted= 41.340000, expected= 41.100000
# predicted= 41.260000, expected= 41.100000
# predicted= 41.180000, expected= 41.100000
# predicted= 41.100000, expected= 41.100000
# predicted= 41.100000, expected= 41.100000
# predicted= 41.100000, expected= 41.100000
# predicted= 41.100000, expected= 41.570000
# predicted= 41.256667, expected= 41.570000
# predicted= 41.413333, expected= 41.570000
# predicted= 41.570000, expected= 41.570000
# predicted= 41.570000, expected= 41.580000
# predicted= 41.573333, expected= 41.700000
# predicted= 41.616667, expected= 41.800000
# predicted= 41.693333, expected= 41.800000
# predicted= 41.766667, expected= 41.900000
# predicted= 41.833333, expected= 42.000000
# predicted= 41.900000, expected= 42.000000
# predicted= 41.966667, expected= 42.000000
# predicted= 42.000000, expected= 42.000000
# predicted= 42.000000, expected= 42.230000
# predicted= 42.076667, expected= 42.230000
# predicted= 42.153333, expected= 42.230000
# predicted= 42.230000, expected= 42.590000
# predicted= 42.350000, expected= 42.600000
# predicted= 42.473333, expected= 42.600000
# predicted= 42.596667, expected= 42.600000
# predicted= 42.600000, expected= 42.600000
# predicted= 42.600000, expected= 42.600000
# predicted= 42.600000, expected= 42.600000
# predicted= 42.600000, expected= 42.600000
# predicted= 42.600000, expected= 42.700000
# predicted= 42.633333, expected= 42.750000
# predicted= 42.683333, expected= 42.810000
# predicted= 42.753333, expected= 42.270000
# predicted= 42.610000, expected= 42.400000
# predicted= 42.493333, expected= 42.400000
# predicted= 42.356667, expected= 42.360000
# predicted= 42.386667, expected= 42.300000
# predicted= 42.353333, expected= 42.160000
# predicted= 42.273333, expected= 41.940000
# predicted= 42.133333, expected= 41.940000
# predicted= 42.013333, expected= 41.950000
# predicted= 41.943333, expected= 41.860000
# predicted= 41.916667, expected= 41.850000
# predicted= 41.886667, expected= 41.850000
# predicted= 41.853333, expected= 41.800000
# predicted= 41.833333, expected= 41.700000
# predicted= 41.783333, expected= 41.700000
# predicted= 41.733333, expected= 41.700000
# predicted= 41.700000, expected= 41.700000
# predicted= 41.700000, expected= 41.700000
# predicted= 41.700000, expected= 42.200000
# predicted= 41.866667, expected= 42.320000
# predicted= 42.073333, expected= 42.360000
# predicted= 42.293333, expected= 42.360000
# predicted= 42.346667, expected= 42.390000
# predicted= 42.370000, expected= 42.400000
# predicted= 42.383333, expected= 42.290000
# predicted= 42.360000, expected= 42.290000
# predicted= 42.326667, expected= 42.300000
# predicted= 42.293333, expected= 42.300000
# predicted= 42.296667, expected= 42.370000
# predicted= 42.323333, expected= 42.370000
# predicted= 42.346667, expected= 42.370000
# predicted= 42.370000, expected= 41.850000
# predicted= 42.196667, expected= 42.140000
# predicted= 42.120000, expected= 42.140000
# predicted= 42.043333, expected= 42.360000
# predicted= 42.213333, expected= 42.360000
# predicted= 42.286667, expected= 42.370000
# predicted= 42.363333, expected= 42.400000
# predicted= 42.376667, expected= 42.400000
# predicted= 42.390000, expected= 42.700000
# predicted= 42.500000, expected= 42.790000
# predicted= 42.630000, expected= 42.800000
# predicted= 42.763333, expected= 42.800000
# predicted= 42.796667, expected= 42.820000
# predicted= 42.806667, expected= 43.000000
# predicted= 42.873333, expected= 43.000000
# predicted= 42.940000, expected= 42.930000
# predicted= 42.976667, expected= 42.930000
# predicted= 42.953333, expected= 42.930000
# predicted= 42.930000, expected= 42.990000
# predicted= 42.950000, expected= 42.990000
# predicted= 42.970000, expected= 42.990000
# predicted= 42.990000, expected= 42.990000
# predicted= 42.990000, expected= 42.990000
# predicted= 42.990000, expected= 43.500000
# predicted= 43.160000, expected= 43.600000
# predicted= 43.363333, expected= 43.700000
# predicted= 43.600000, expected= 43.810000
# predicted= 43.703333, expected= 43.810000
# predicted= 43.773333, expected= 43.850000
# predicted= 43.823333, expected= 43.900000
# predicted= 43.853333, expected= 44.000000
# predicted= 43.916667, expected= 44.000000
# predicted= 43.966667, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.100000
# predicted= 44.033333, expected= 44.000000
# predicted= 44.033333, expected= 44.000000
# predicted= 44.033333, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# predicted= 44.000000, expected= 44.000000
# ...
# predicted= 42.880000, expected= 42.800000
# predicted= 42.813333, expected= 43.000000
# predicted= 42.873333, expected= 43.490000
# predicted= 43.096667, expected= 43.000000
# predicted= 43.163333, expected= 43.550000
# predicted= 43.346667, expected= 43.620000
# predicted= 43.390000, expected= 43.920000
# predicted= 43.696667, expected= 43.550000
# predicted= 43.696667, expected= 43.600000
# predicted= 43.690000, expected= 43.600000
# predicted= 43.583333, expected= 43.900000
# predicted= 43.700000, expected= 44.000000
# predicted= 43.833333, expected= 44.000000
# predicted= 43.966667, expected= 44.000000
# predicted= 44.000000, expected= 44.020000
# predicted= 44.006667, expected= 43.080000
# predicted= 43.700000, expected= 43.080000
# predicted= 43.393333, expected= 43.410000
# predicted= 43.190000, expected= 43.410000
# predicted= 43.300000, expected= 44.020000
# predicted= 43.613333, expected= 44.040000
# predicted= 43.823333, expected= 44.490000
# predicted= 44.183333, expected= 44.500000
# predicted= 44.343333, expected= 44.500000
# predicted= 44.496667, expected= 45.000000
# predicted= 44.666667, expected= 45.500000
# predicted= 45.000000, expected= 46.000000
# predicted= 45.500000, expected= 46.000000
# predicted= 45.833333, expected= 46.000000
# predicted= 46.000000, expected= 46.500000
# predicted= 46.166667, expected= 46.500000
# predicted= 46.333333, expected= 47.000000
# predicted= 46.666667, expected= 47.000000
# predicted= 46.833333, expected= 46.750000
# predicted= 46.916667, expected= 46.980000
# predicted= 46.910000, expected= 47.000000
# predicted= 46.910000, expected= 47.440000
# predicted= 47.140000, expected= 45.420000
# predicted= 46.620000, expected= 47.000000
# predicted= 46.620000, expected= 47.000000
# predicted= 46.473333, expected= 47.300000
# predicted= 47.100000, expected= 47.440000
# predicted= 47.246667, expected= 47.000000
# predicted= 47.246667, expected= 47.440000
# predicted= 47.293333, expected= 47.440000
# predicted= 47.293333, expected= 47.700000
# predicted= 47.526667, expected= 47.750000
# predicted= 47.630000, expected= 47.920000
# predicted= 47.790000, expected= 47.920000
# predicted= 47.863333, expected= 47.920000
# predicted= 47.920000, expected= 48.000000
# predicted= 47.946667, expected= 48.000000
# predicted= 47.973333, expected= 48.000000
# predicted= 48.000000, expected= 48.000000
# predicted= 48.000000, expected= 48.000000
# predicted= 48.000000, expected= 48.000000
# predicted= 48.000000, expected= 48.000000
# predicted= 48.000000, expected= 48.200000
# predicted= 48.066667, expected= 49.420000
# predicted= 48.540000, expected= 50.000000
# predicted= 49.206667, expected= 50.000000
# predicted= 49.806667, expected= 50.000000
# predicted= 50.000000, expected= 50.000000
# predicted= 50.000000, expected= 50.000000
# predicted= 50.000000, expected= 50.000000
# predicted= 50.000000, expected= 52.090000
# predicted= 50.696667, expected= 52.100000
# predicted= 51.396667, expected= 52.100000
# predicted= 52.096667, expected= 52.100000
# predicted= 52.100000, expected= 52.100000
# predicted= 52.100000, expected= 52.100000
# predicted= 52.100000, expected= 52.100000
# predicted= 52.100000, expected= 52.500000
# predicted= 52.233333, expected= 52.500000
# predicted= 52.366667, expected= 52.500000
# predicted= 52.500000, expected= 53.000000
# predicted= 52.666667, expected= 52.500000
# predicted= 52.666667, expected= 54.900000
# predicted= 53.466667, expected= 54.990000
# predicted= 54.130000, expected= 54.990000
# predicted= 54.960000, expected= 54.990000
# predicted= 54.990000, expected= 54.990000
# predicted= 54.990000, expected= 54.990000
# predicted= 54.990000, expected= 54.990000
# predicted= 54.990000, expected= 54.990000
# predicted= 54.990000, expected= 54.990000
# predicted= 54.990000, expected= 55.000000
# predicted= 54.993333, expected= 55.000000
# predicted= 54.996667, expected= 55.000000
# predicted= 55.000000, expected= 55.000000
# predicted= 55.000000, expected= 55.000000
# predicted= 55.000000, expected= 55.000000
# predicted= 55.000000, expected= 55.000000
# predicted= 55.000000, expected= 56.000000
# predicted= 55.333333, expected= 56.000000
# predicted= 55.666667, expected= 56.000000
# predicted= 56.000000, expected= 55.000000
# predicted= 55.666667, expected= 52.500000
# predicted= 54.500000, expected= 52.520000
# predicted= 53.340000, expected= 52.520000
# predicted= 52.513333, expected= 52.520000
# predicted= 52.520000, expected= 52.520000
# predicted= 52.520000, expected= 52.500000
# predicted= 52.513333, expected= 52.500000
# predicted= 52.506667, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 52.500000
# predicted= 52.500000, expected= 47.850000
# predicted= 50.950000, expected= 48.360000
# predicted= 49.570000, expected= 48.360000
# predicted= 48.190000, expected= 48.560000
# predicted= 48.426667, expected= 48.560000
# predicted= 48.493333, expected= 48.560000
# predicted= 48.560000, expected= 48.560000
# predicted= 48.560000, expected= 48.560000
# predicted= 48.560000, expected= 48.560000
# predicted= 48.560000, expected= 48.560000
# predicted= 48.560000, expected= 48.560000
# predicted= 48.560000, expected= 47.500000
# predicted= 48.206667, expected= 48.560000
# predicted= 48.206667, expected= 48.000000
# predicted= 48.020000, expected= 48.460000
# predicted= 48.340000, expected= 47.920000
# predicted= 48.126667, expected= 48.460000
# predicted= 48.280000, expected= 48.560000
# predicted= 48.313333, expected= 48.560000
# predicted= 48.526667, expected= 48.560000
# predicted= 48.560000, expected= 48.650000
# predicted= 48.590000, expected= 48.120000
# predicted= 48.443333, expected= 48.600000
# predicted= 48.456667, expected= 48.610000
# predicted= 48.443333, expected= 48.650000
# predicted= 48.620000, expected= 49.700000
# predicted= 48.986667, expected= 50.000000
# predicted= 49.450000, expected= 48.120000
# predicted= 49.273333, expected= 47.820000
# predicted= 48.646667, expected= 47.820000
# predicted= 47.920000, expected= 49.110000
# predicted= 48.250000, expected= 49.800000
# predicted= 48.910000, expected= 49.840000
# predicted= 49.583333, expected= 50.000000
# predicted= 49.880000, expected= 50.040000
# predicted= 49.960000, expected= 50.470000
# predicted= 50.170000, expected= 51.000000
# predicted= 50.503333, expected= 50.950000
# predicted= 50.806667, expected= 48.490000
# predicted= 50.146667, expected= 48.490000
# predicted= 49.310000, expected= 48.470000
# predicted= 48.483333, expected= 48.470000
# predicted= 48.476667, expected= 48.470000
# predicted= 48.470000, expected= 46.100000
# predicted= 47.680000, expected= 46.100000
# predicted= 46.890000, expected= 46.100000
# predicted= 46.100000, expected= 46.100000
# predicted= 46.100000, expected= 46.000000
# predicted= 46.066667, expected= 45.300000
# predicted= 45.800000, expected= 45.200000
# predicted= 45.500000, expected= 45.160000
# predicted= 45.220000, expected= 45.000000
# predicted= 45.120000, expected= 45.000000
# predicted= 45.053333, expected= 45.690000
# predicted= 45.230000, expected= 46.990000
# predicted= 45.893333, expected= 45.040000
# predicted= 45.906667, expected= 45.040000
# predicted= 45.690000, expected= 45.040000
# predicted= 45.040000, expected= 45.040000
# predicted= 45.040000, expected= 45.040000
# predicted= 45.040000, expected= 45.020000
# predicted= 45.033333, expected= 45.000000
# predicted= 45.020000, expected= 45.200000
# predicted= 45.073333, expected= 45.000000
# predicted= 45.066667, expected= 45.000000
# predicted= 45.066667, expected= 44.960000
# predicted= 44.986667, expected= 44.500000
# predicted= 44.820000, expected= 44.200000
# predicted= 44.553333, expected= 44.200000
# predicted= 44.300000, expected= 43.980000
# predicted= 44.126667, expected= 43.980000
# predicted= 44.053333, expected= 43.960000
# predicted= 43.973333, expected= 43.960000
# predicted= 43.966667, expected= 43.940000
# predicted= 43.953333, expected= 43.820000
# predicted= 43.906667, expected= 44.990000
# predicted= 44.250000, expected= 44.990000
# predicted= 44.600000, expected= 43.500000
# predicted= 44.493333, expected= 44.990000
# predicted= 44.493333, expected= 43.570000
# predicted= 44.020000, expected= 43.570000
# predicted= 44.043333, expected= 43.570000
# predicted= 43.570000, expected= 43.570000
# predicted= 43.570000, expected= 43.570000
# predicted= 43.570000, expected= 43.570000
# predicted= 43.570000, expected= 44.900000
# predicted= 44.013333, expected= 44.900000
# predicted= 44.456667, expected= 43.570000
# predicted= 44.456667, expected= 43.570000
# predicted= 44.013333, expected= 44.990000
# predicted= 44.043333, expected= 44.990000
# predicted= 44.516667, expected= 43.570000
# predicted= 44.516667, expected= 43.550000
# predicted= 44.036667, expected= 43.500000
# predicted= 43.540000, expected= 43.390000
# predicted= 43.480000, expected= 43.100000
# predicted= 43.330000, expected= 42.820000
# predicted= 43.103333, expected= 42.820000
# predicted= 42.913333, expected= 42.800000
# predicted= 42.813333, expected= 42.400000
# predicted= 42.673333, expected= 42.000000
# predicted= 42.400000, expected= 42.000000
# predicted= 42.133333, expected= 42.000000
# predicted= 42.000000, expected= 41.310000
# predicted= 41.770000, expected= 41.200000
# predicted= 41.503333, expected= 41.370000
# predicted= 41.293333, expected= 41.390000
# predicted= 41.320000, expected= 41.200000
# predicted= 41.320000, expected= 41.700000
# predicted= 41.430000, expected= 41.340000
# predicted= 41.413333, expected= 41.340000
# predicted= 41.460000, expected= 41.220000
# predicted= 41.300000, expected= 41.020000
# predicted= 41.193333, expected= 41.020000
# predicted= 41.086667, expected= 41.000000
# predicted= 41.013333, expected= 41.000000
# predicted= 41.006667, expected= 40.750000
# predicted= 40.916667, expected= 40.750000
# predicted= 40.833333, expected= 40.750000
# predicted= 40.750000, expected= 40.750000
# predicted= 40.750000, expected= 40.750000
# predicted= 40.750000, expected= 40.750000
# predicted= 40.750000, expected= 40.370000
# predicted= 40.623333, expected= 40.390000
# predicted= 40.503333, expected= 40.080000
# predicted= 40.280000, expected= 41.380000
# predicted= 40.616667, expected= 41.990000
# predicted= 41.150000, expected= 41.990000
# predicted= 41.786667, expected= 42.390000
# predicted= 42.123333, expected= 41.030000
# predicted= 41.803333, expected= 41.030000
# predicted= 41.483333, expected= 41.030000
# predicted= 41.030000, expected= 41.030000
# predicted= 41.030000, expected= 41.190000
# predicted= 41.083333, expected= 41.190000
# predicted= 41.136667, expected= 41.000000
# predicted= 41.126667, expected= 40.070000
# predicted= 40.753333, expected= 40.600000
# predicted= 40.556667, expected= 40.920000
# predicted= 40.530000, expected= 41.000000
# predicted= 40.840000, expected= 41.000000
# predicted= 40.973333, expected= 41.000000
# predicted= 41.000000, expected= 39.780000
# predicted= 40.593333, expected= 41.000000
# predicted= 40.593333, expected= 41.020000
# predicted= 40.600000, expected= 41.020000
# predicted= 41.013333, expected= 41.020000
# predicted= 41.020000, expected= 41.020000
# predicted= 41.020000, expected= 41.000000
# predicted= 41.013333, expected= 41.000000
# predicted= 41.006667, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 41.000000
# predicted= 41.000000, expected= 40.390000
# predicted= 40.796667, expected= 40.090000
# predicted= 40.493333, expected= 40.090000
# predicted= 40.190000, expected= 40.000000
# predicted= 40.060000, expected= 40.000000
# predicted= 40.030000, expected= 40.820000
# predicted= 40.273333, expected= 40.900000
# predicted= 40.573333, expected= 39.760000
# predicted= 40.493333, expected= 40.940000
# predicted= 40.533333, expected= 41.000000
# predicted= 40.566667, expected= 40.760000
# predicted= 40.900000, expected= 39.530000
# predicted= 40.430000, expected= 42.390000
# predicted= 40.893333, expected= 41.000000
# predicted= 40.973333, expected= 41.000000
# predicted= 41.463333, expected= 40.720000
# predicted= 40.906667, expected= 40.720000
# predicted= 40.813333, expected= 40.720000
# predicted= 40.720000, expected= 40.720000
# predicted= 40.720000, expected= 41.000000
# predicted= 40.813333, expected= 39.000000
# predicted= 40.240000, expected= 38.760000
# predicted= 39.586667, expected= 41.000000
# predicted= 39.586667, expected= 38.760000
# predicted= 39.506667, expected= 38.750000
# predicted= 39.503333, expected= 38.600000
# predicted= 38.703333, expected= 38.500000
# predicted= 38.616667, expected= 38.000000
# predicted= 38.366667, expected= 38.000000
# predicted= 38.166667, expected= 37.000000
# predicted= 37.666667, expected= 41.000000
# predicted= 38.666667, expected= 38.600000
# predicted= 38.866667, expected= 41.000000
# predicted= 40.200000, expected= 38.600000
# predicted= 39.400000, expected= 38.000000
# predicted= 39.200000, expected= 43.000000
# predicted= 39.866667, expected= 41.000000
# predicted= 40.666667, expected= 43.000000
# predicted= 42.333333, expected= 43.800000
# predicted= 42.600000, expected= 41.000000
# predicted= 42.600000, expected= 44.770000
# predicted= 43.190000, expected= 45.160000
# predicted= 43.643333, expected= 41.000000
# predicted= 43.643333, expected= 46.950000
# predicted= 44.370000, expected= 46.950000
# predicted= 44.966667, expected= 46.950000
# predicted= 46.950000, expected= 46.950000
# predicted= 46.950000, expected= 47.430000
# predicted= 47.110000, expected= 44.000000
# predicted= 46.126667, expected= 42.570000
# predicted= 44.666667, expected= 42.000000
# predicted= 42.856667, expected= 41.000000
# predicted= 41.856667, expected= 41.920000
# predicted= 41.640000, expected= 41.490000
# predicted= 41.470000, expected= 42.400000
# predicted= 41.936667, expected= 42.400000
# predicted= 42.096667, expected= 44.680000
# predicted= 43.160000, expected= 41.490000
# predicted= 42.856667, expected= 44.680000
# predicted= 43.616667, expected= 44.680000
# predicted= 43.616667, expected= 44.000000
# predicted= 44.453333, expected= 44.680000
# predicted= 44.453333, expected= 44.000000
# predicted= 44.226667, expected= 44.120000
# predicted= 44.266667, expected= 44.000000
# predicted= 44.040000, expected= 45.000000
# predicted= 44.373333, expected= 44.600000
# predicted= 44.533333, expected= 45.020000
# predicted= 44.873333, expected= 44.000000
# predicted= 44.540000, expected= 44.000000
# predicted= 44.340000, expected= 45.020000
# predicted= 44.340000, expected= 45.000000
# predicted= 44.673333, expected= 45.000000
# predicted= 45.006667, expected= 42.000000
# predicted= 44.000000, expected= 45.000000
# predicted= 44.000000, expected= 42.000000
# predicted= 43.000000, expected= 38.000000
# predicted= 41.666667, expected= 45.000000
# predicted= 41.666667, expected= 45.000000
# predicted= 42.666667, expected= 45.000000
# predicted= 45.000000, expected= 44.100000
# predicted= 44.700000, expected= 45.000000
# predicted= 44.700000, expected= 44.500000
# predicted= 44.533333, expected= 61.990000
# predicted= 50.496667, expected= 45.000000
# predicted= 50.496667, expected= 45.000000
# predicted= 50.663333, expected= 45.000000
# predicted= 45.000000, expected= 44.100000
# predicted= 44.700000, expected= 45.000000
# predicted= 44.700000, expected= 44.100000
# predicted= 44.400000, expected= 46.950000
# predicted= 45.350000, expected= 46.950000
# predicted= 46.000000, expected= 47.440000
# predicted= 47.113333, expected= 47.440000
# predicted= 47.276667, expected= 47.920000
# predicted= 47.600000, expected= 47.440000
# predicted= 47.600000, expected= 47.920000
# predicted= 47.760000, expected= 48.980000
# predicted= 48.113333, expected= 47.440000
# predicted= 48.113333, expected= 45.000000
# predicted= 47.140000, expected= 45.000000
# predicted= 45.813333, expected= 46.000000
# predicted= 45.333333, expected= 47.440000
# predicted= 46.146667, expected= 47.400000
# predicted= 46.946667, expected= 47.440000
# Test RMSE: 0.717
